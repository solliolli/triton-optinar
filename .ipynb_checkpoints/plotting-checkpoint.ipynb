# %%
using DelimitedFiles, Plots
pi_sample = readdlm("results/singlerun.csv")
plot(1:length(pi_sample), pi_sample, label="Estimate of the value of π", ylabel="Estimate", xlabel="Iteration")

# %%
using DelimitedFiles, Plots
plt = plot(ylabel="Estimate", xlabel="Iteration")
for i in 1:50
    pi_sample = readdlm("results/array_$(i).csv")
    plot!(1:10:length(pi_sample), pi_sample[1:10:end], label=false, color=palette(:tab10)[1])
end
plt
